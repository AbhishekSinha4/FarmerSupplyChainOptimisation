# %%
import pandas as pd

# %%
beansData = pd.read_csv("beansData//Beans_Price_Report.csv")
beansData.head()
# Out:
#    Sl. No.   District      Market Commodity        Variety Grade  MinPrice  \
# 0        0  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ      2000
# 1        1  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ      1600
# 2        2  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ      1800
# 3        3  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ      2000
# 4        4  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ      2000
#
#    MaxPrice  ModalPrice  PriceDate
# 0      2800        2400  15-Feb-20
# 1      2000        1800  14-Feb-20
# 2      2200        2000  13-Feb-20
# 3      2400        2200  12-Feb-20
# 4      2400        2200  11-Feb-20

# %%
# minimum and maximum dates printed

print("From: ",pd.to_datetime(beansData["PriceDate"]).min().date())
print("To: ",pd.to_datetime(beansData["PriceDate"]).max().date())
# Out:
# From:  2018-01-01
# To:  2020-02-15

# %%
# adding a weekday column for the dates we have data on.

beansData["weekday"] = beansData["PriceDate"].apply(lambda x: pd.to_datetime(x).date().weekday(), 1)
beansData.head()
# Out:
#    Sl. No.   District      Market Commodity        Variety Grade  MinPrice  \
# 0        0  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ      2000
# 1        1  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ      1600
# 2        2  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ      1800
# 3        3  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ      2000
# 4        4  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ      2000
#
#    MaxPrice  ModalPrice  PriceDate  weekday
# 0      2800        2400  15-Feb-20        5
# 1      2000        1800  14-Feb-20        4
# 2      2200        2000  13-Feb-20        3
# 3      2400        2200  12-Feb-20        2
# 4      2400        2200  11-Feb-20        1

# %%
beansData.groupby(["weekday","Market"])["PriceDate"].count()
# Out:
# weekday  Market
# 0        Binny Mill (F&V), Bangalore     89
#          Ramanagara                     106
# 1        Binny Mill (F&V), Bangalore     87
#          Ramanagara                     106
# 2        Binny Mill (F&V), Bangalore     84
#          Ramanagara                     106
# 3        Binny Mill (F&V), Bangalore     87
#          Ramanagara                     106
# 4        Binny Mill (F&V), Bangalore     88
#          Ramanagara                     107
# 5        Binny Mill (F&V), Bangalore     59
#          Ramanagara                     104
# 6        Ramanagara                       2
# Name: PriceDate, dtype: int64

# %%
from calendar import month_abbr
from math import isnan
import numpy as np
import matplotlib.pyplot as plt
import datetime


def rowFiller(x):
    indices = [x-7, x-14, x-21]     # indices of data points to be averaged for interpolation.
    MinPrice= sum([finalFrame.loc[i,"MinPrice"] for i in indices if i>=0])/3
    MaxPrice= sum([finalFrame.loc[i,"MaxPrice"] for i in indices if i>=0])/3
    ModalPrice= sum([finalFrame.loc[i,"ModalPrice"] for i in indices if i>=0])/3
    print(MinPrice, MaxPrice, ModalPrice)
    temp = finalFrame.loc[x-7]
    temp["PriceDate"]= dateFormatChange((pd.to_datetime(temp["PriceDate"])+datetime.timedelta(days=7)))
    temp["date"]= temp["PriceDate"]
    temp["MinPrice"]= MinPrice
    temp["MaxPrice"]= MaxPrice
    temp["ModalPrice"]= ModalPrice
    return temp


def dateFormatChange(x):    # function to change format of data from yyyy-mm-dd to dd-mon-yy. Eg. 2019-12-10 -> 10-Dec-19
    x = str(x.date()).split("-")[::-1]
    x[1] = month_abbr[int(x[1])]
    x[2] = x[2][2:]
    return "-".join(x)

# %% [markdown]
# ## Ramanagara

# %%
# creating a table with all dates from minDate to maxDate, to figure out missing rows.
datelist = pd.date_range(pd.to_datetime(beansData["PriceDate"]).min().date(),end = pd.to_datetime(beansData["PriceDate"]).max().date()).to_pydatetime().tolist()
finalFrame = pd.DataFrame({"date": datelist})
print(finalFrame.head())
finalFrame["date"] = finalFrame.date.apply(dateFormatChange, 1)
finalFrame.head()
# Out:
#         date
# 0 2018-01-01
# 1 2018-01-02
# 2 2018-01-03
# 3 2018-01-04
# 4 2018-01-05
#         date
# 0  01-Jan-18
# 1  02-Jan-18
# 2  03-Jan-18
# 3  04-Jan-18
# 4  05-Jan-18

# %%
# Joining the all date table with the beans data for Binny Mill marketplace and filling the rows we have data for. 

finalFrame = pd.merge(finalFrame, beansData[beansData.Market=='Ramanagara'], left_on='date', right_on='PriceDate', how='left')
finalFrame
# Out:
#           date  Sl. No.   District      Market Commodity        Variety Grade  \
# 0    01-Jan-18    636.0  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ
# 1    02-Jan-18    635.0  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ
# 2    03-Jan-18    634.0  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ
# 3    04-Jan-18    633.0  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ
# 4    05-Jan-18    632.0  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ
# ..         ...      ...        ...         ...       ...            ...   ...
# 771  11-Feb-20      4.0  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ
# 772  12-Feb-20      3.0  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ
# 773  13-Feb-20      2.0  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ
# 774  14-Feb-20      1.0  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ
# 775  15-Feb-20      0.0  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ
#
#      MinPrice  MaxPrice  ModalPrice  PriceDate  weekday
# 0      1600.0    2000.0      1800.0  01-Jan-18      0.0
# 1      1600.0    2000.0      1800.0  02-Jan-18      1.0
# 2      1600.0    2000.0      1800.0  03-Jan-18      2.0
# 3      1600.0    2000.0      1800.0  04-Jan-18      3.0
# 4      1200.0    1600.0      1400.0  05-Jan-18      4.0
# ..        ...       ...         ...        ...      ...
# 771    2000.0    2400.0      2200.0  11-Feb-20      1.0
# 772    2000.0    2400.0      2200.0  12-Feb-20      2.0
# 773    1800.0    2200.0      2000.0  13-Feb-20      3.0
# 774    1600.0    2000.0      1800.0  14-Feb-20      4.0
# 775    2000.0    2800.0      2400.0  15-Feb-20      5.0
#
# [776 rows x 12 columns]

# %%
# Filling in missing weekday numbers.  Mon-> 0, Tue-> 1 ... , Sat->5, Sun-> 6 

for i,j in finalFrame.iterrows():
    if(isnan(j.weekday)):
        finalFrame.loc[i,"weekday"] = (finalFrame.loc[i-1,"weekday"]+1)%7
finalFrame
# Out:
#           date  Sl. No.   District      Market Commodity        Variety Grade  \
# 0    01-Jan-18    636.0  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ
# 1    02-Jan-18    635.0  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ
# 2    03-Jan-18    634.0  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ
# 3    04-Jan-18    633.0  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ
# 4    05-Jan-18    632.0  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ
# ..         ...      ...        ...         ...       ...            ...   ...
# 771  11-Feb-20      4.0  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ
# 772  12-Feb-20      3.0  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ
# 773  13-Feb-20      2.0  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ
# 774  14-Feb-20      1.0  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ
# 775  15-Feb-20      0.0  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ
#
#      MinPrice  MaxPrice  ModalPrice  PriceDate  weekday
# 0      1600.0    2000.0      1800.0  01-Jan-18      0.0
# 1      1600.0    2000.0      1800.0  02-Jan-18      1.0
# 2      1600.0    2000.0      1800.0  03-Jan-18      2.0
# 3      1600.0    2000.0      1800.0  04-Jan-18      3.0
# 4      1200.0    1600.0      1400.0  05-Jan-18      4.0
# ..        ...       ...         ...        ...      ...
# 771    2000.0    2400.0      2200.0  11-Feb-20      1.0
# 772    2000.0    2400.0      2200.0  12-Feb-20      2.0
# 773    1800.0    2200.0      2000.0  13-Feb-20      3.0
# 774    1600.0    2000.0      1800.0  14-Feb-20      4.0
# 775    2000.0    2800.0      2400.0  15-Feb-20      5.0
#
# [776 rows x 12 columns]

# %%
# Printing the number of Non-Sunday Null rows and their indices

print(finalFrame[(np.isnan(finalFrame.ModalPrice)) & (finalFrame.weekday != 6.0) ].head())
nanIndices = finalFrame[(np.isnan(finalFrame.ModalPrice)) & (finalFrame.weekday != 6.0) ].index
print("Ramanagara Null rows: ",nanIndices,"\nNumber of null rows for Ramanagara: ",len(nanIndices))
# Out:
#           date  Sl. No. District Market Commodity Variety Grade  MinPrice  \
# 109  20-Apr-18      NaN      NaN    NaN       NaN     NaN   NaN       NaN
# 110  21-Apr-18      NaN      NaN    NaN       NaN     NaN   NaN       NaN
# 112  23-Apr-18      NaN      NaN    NaN       NaN     NaN   NaN       NaN
# 113  24-Apr-18      NaN      NaN    NaN       NaN     NaN   NaN       NaN
# 114  25-Apr-18      NaN      NaN    NaN       NaN     NaN   NaN       NaN
#
#      MaxPrice  ModalPrice PriceDate  weekday
# 109       NaN         NaN       NaN      4.0
# 110       NaN         NaN       NaN      5.0
# 112       NaN         NaN       NaN      0.0
# 113       NaN         NaN       NaN      1.0
# 114       NaN         NaN       NaN      2.0
# Ramanagara Null rows:  Int64Index([109, 110, 112, 113, 114, 131, 290, 358, 472, 542, 543, 544, 546,
#             547, 548, 549, 550, 551, 553, 554, 555, 556, 557, 558, 609, 644,
#             645, 723, 740, 744, 754],
#            dtype='int64')
# Number of null rows for Ramanagara:  31

# %% [markdown]
# ### Some Plots exploring the Data

# %%
plt.title("Plotting all data, daywise min-price")
plt.plot(beansData[beansData.Market == "Ramanagara"].ModalPrice)
plt.show()

# %%
# Plots for the modal price changes vs day number (index) for different weekdays, before interpolation
 
days = ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
for i in range(7):
    plt.title(days[i])
    plt.plot(finalFrame[finalFrame.weekday == float(i)].ModalPrice)
    plt.show()

# %% [markdown]
# ### Interpolation on null rows

# %%
print(rowFiller(101))
# Out:
# 2533.3333333333335 3200.0 2866.6666666666665
# date              12-Apr-18
# Sl. No.                 555
# District          Bangalore
# Market           Ramanagara
# Commodity             Beans
# Variety       Beans (Whole)
# Grade                   FAQ
# MinPrice            2533.33
# MaxPrice               3200
# ModalPrice          2866.67
# PriceDate         12-Apr-18
# weekday                   3
# Name: 94, dtype: object
# C:\Users\sunri\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# C:\Users\sunri\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# C:\Users\sunri\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\sunri\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\sunri\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Filling the null rows with the interpolated values

for i in nanIndices:
#     print(finalFrame.loc[i])
    finalFrame.loc[i] = rowFiller(i)
#     print(finalFrame.loc[i],"\n\n")
# Out:
# 2666.6666666666665 3333.3333333333335 3000.0
# 2800.0 3466.6666666666665 3133.3333333333335
# 2800.0 3333.3333333333335 3066.6666666666665
# 2933.3333333333335 3733.3333333333335 3333.3333333333335
# 2133.3333333333335 2933.3333333333335 2533.3333333333335
# 3333.3333333333335 4088.8888888888887 3711.1111111111113
# 2533.3333333333335 3200.0 2866.6666666666665
0  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ
#
#         MinPrice     MaxPrice   ModalPrice  PriceDate  weekday
# 108  2400.000000  3200.000000  2800.000000  19-Apr-18      3.0
# 109  2666.666667  3333.333333  3000.000000  20-Apr-18      4.0
# 110  2800.000000  3466.666667  3133.333333  21-Apr-18      5.0
# 111          NaN          NaN          NaN        NaN      6.0
# 112  2800.000000  3333.333333  3066.666667  23-Apr-18      0.0

# %%
# checking whether any null rows are left after interpolation (that are not Sundays)

print(finalFrame[(np.isnan(finalFrame.ModalPrice)) & (finalFrame.weekday != 6.0) ].head())
nanIndices = finalFrame[(np.isnan(finalFrame.ModalPrice)) & (finalFrame.weekday != 6.0) ].index
print("Null rows: ",nanIndices,"\nNumber of null rows: ",len(nanIndices))
# Out:
# Empty DataFrame
# Columns: [date, Sl. No., District, Market, Commodity, Variety, Grade, MinPrice, MaxPrice, ModalPrice, PriceDate, weekday]
# Index: []
# Null rows:  Int64Index([], dtype='int64')
# Number of null rows:  0

# %% [markdown]
# ### Replotting the weekday-wise plots after interpolation

# %%
for i in range(7):
    plt.title(days[i])
    plt.plot(finalFrame[finalFrame.weekday == float(i)].ModalPrice)
    plt.show()

# %% [markdown]
# ## For Binny Mill (F&V), Bangalore

# %%
# creating a table with all dates from minDate to maxDate, to figure out missing rows.

datelist = pd.date_range(pd.to_datetime(beansData["PriceDate"]).min().date(),end = pd.to_datetime(beansData["PriceDate"]).max().date()).to_pydatetime().tolist()
finalFrameBinny = pd.DataFrame({"date": datelist})
print(finalFrameBinny.head())
finalFrameBinny["date"] = finalFrameBinny.date.apply(dateFormatChange, 1)
finalFrameBinny.head()
# Out:
#         date
# 0 2018-01-01
# 1 2018-01-02
# 2 2018-01-03
# 3 2018-01-04
# 4 2018-01-05
#         date
# 0  01-Jan-18
# 1  02-Jan-18
# 2  03-Jan-18
# 3  04-Jan-18
# 4  05-Jan-18

# %%
# Joining the all date table with the beans data for Binny Mill marketplace and filling the rows we have data for. 
finalFrameBinny = pd.merge(finalFrameBinny, beansData[beansData.Market=='Binny Mill (F&V), Bangalore'], left_on='date', right_on='PriceDate', how='left')
finalFrameBinny
# Out:
#           date  Sl. No.   District                       Market Commodity  \
# 0    01-Jan-18    493.0  Bangalore  Binny Mill (F&V), Bangalore     Beans
# 1    02-Jan-18    492.0  Bangalore  Binny Mill (F&V), Bangalore     Beans
# 2    03-Jan-18    491.0  Bangalore  Binny Mill (F&V), Bangalore     Beans
# 3    04-Jan-18    490.0  Bangalore  Binny Mill (F&V), Bangalore     Beans
# 4    05-Jan-18    489.0  Bangalore  Binny Mill (F&V), Bangalore     Beans
# ..         ...      ...        ...                          ...       ...
# 771  11-Feb-20      4.0  Bangalore  Binny Mill (F&V), Bangalore     Beans
# 772  12-Feb-20      3.0  Bangalore  Binny Mill (F&V), Bangalore     Beans
# 773  13-Feb-20      2.0  Bangalore  Binny Mill (F&V), Bangalore     Beans
# 774  14-Feb-20      1.0  Bangalore  Binny Mill (F&V), Bangalore     Beans
# 775  15-Feb-20      0.0  Bangalore  Binny Mill (F&V), Bangalore     Beans
#
#            Variety Grade  MinPrice  MaxPrice  ModalPrice  PriceDate  weekday
# 0    Beans (Whole)   FAQ    1800.0    2500.0      2200.0  01-Jan-18      0.0
# 1    Beans (Whole)   FAQ    1800.0    2500.0      2000.0  02-Jan-18      1.0
# 2    Beans (Whole)   FAQ    1600.0    2000.0      1800.0  03-Jan-18      2.0
# 3    Beans (Whole)   FAQ    1400.0    1800.0      1600.0  04-Jan-18      3.0
# 4    Beans (Whole)   FAQ    1200.0    1600.0      1400.0  05-Jan-18      4.0
# ..             ...   ...       ...       ...         ...        ...      ...
# 771  Beans (Whole)   FAQ    1600.0    2000.0      1800.0  11-Feb-20      1.0
# 772  Beans (Whole)   FAQ    1600.0    2000.0      1800.0  12-Feb-20      2.0
# 773  Beans (Whole)   FAQ    1600.0    2000.0      1800.0  13-Feb-20      3.0
# 774  Beans (Whole)   FAQ    1400.0    2000.0      1800.0  14-Feb-20      4.0
# 775  Beans (Whole)   FAQ    1600.0    2000.0      1800.0  15-Feb-20      5.0
#
# [776 rows x 12 columns]

# %%
# Filling in missing weekday numbers.  Mon-> 0, Tue-> 1 ... , Sat->5, Sun-> 6 

for i,j in finalFrameBinny.iterrows():
    if(isnan(j.weekday)):
        finalFrameBinny.loc[i,"weekday"] = (finalFrameBinny.loc[i-1,"weekday"]+1)%7
finalFrameBinny
# Out:
#           date  Sl. No.   District                       Market Commodity  \
# 0    01-Jan-18    493.0  Bangalore  Binny Mill (F&V), Bangalore     Beans
# 1    02-Jan-18    492.0  Bangalore  Binny Mill (F&V), Bangalore     Beans
# 2    03-Jan-18    491.0  Bangalore  Binny Mill (F&V), Bangalore     Beans
# 3    04-Jan-18    490.0  Bangalore  Binny Mill (F&V), Bangalore     Beans
# 4    05-Jan-18    489.0  Bangalore  Binny Mill (F&V), Bangalore     Beans
# ..         ...      ...        ...                          ...       ...
# 771  11-Feb-20      4.0  Bangalore  Binny Mill (F&V), Bangalore     Beans
# 772  12-Feb-20      3.0  Bangalore  Binny Mill (F&V), Bangalore     Beans
# 773  13-Feb-20      2.0  Bangalore  Binny Mill (F&V), Bangalore     Beans
# 774  14-Feb-20      1.0  Bangalore  Binny Mill (F&V), Bangalore     Beans
# 775  15-Feb-20      0.0  Bangalore  Binny Mill (F&V), Bangalore     Beans
#
#            Variety Grade  MinPrice  MaxPrice  ModalPrice  PriceDate  weekday
# 0    Beans (Whole)   FAQ    1800.0    2500.0      2200.0  01-Jan-18      0.0
# 1    Beans (Whole)   FAQ    1800.0    2500.0      2000.0  02-Jan-18      1.0
# 2    Beans (Whole)   FAQ    1600.0    2000.0      1800.0  03-Jan-18      2.0
# 3    Beans (Whole)   FAQ    1400.0    1800.0      1600.0  04-Jan-18      3.0
# 4    Beans (Whole)   FAQ    1200.0    1600.0      1400.0  05-Jan-18      4.0
# ..             ...   ...       ...       ...         ...        ...      ...
# 771  Beans (Whole)   FAQ    1600.0    2000.0      1800.0  11-Feb-20      1.0
# 772  Beans (Whole)   FAQ    1600.0    2000.0      1800.0  12-Feb-20      2.0
# 773  Beans (Whole)   FAQ    1600.0    2000.0      1800.0  13-Feb-20      3.0
# 774  Beans (Whole)   FAQ    1400.0    2000.0      1800.0  14-Feb-20      4.0
# 775  Beans (Whole)   FAQ    1600.0    2000.0      1800.0  15-Feb-20      5.0
#
# [776 rows x 12 columns]

# %%
# Printing the number of Non-Sunday Null rows and their indices

print(finalFrameBinny[(np.isnan(finalFrameBinny.ModalPrice)) & (finalFrameBinny.weekday != 6.0) ].head())
nanIndicesBinny = finalFrameBinny[(np.isnan(finalFrameBinny.ModalPrice)) & (finalFrameBinny.weekday != 6.0) ].index
print("Null rows: ",nanIndicesBinny,"\nNumber of null rows: ",len(nanIndicesBinny))
# Out:
#          date  Sl. No. District Market Commodity Variety Grade  MinPrice  \
# 12  13-Jan-18      NaN      NaN    NaN       NaN     NaN   NaN       NaN
# 14  15-Jan-18      NaN      NaN    NaN       NaN     NaN   NaN       NaN
# 19  20-Jan-18      NaN      NaN    NaN       NaN     NaN   NaN       NaN
# 24  25-Jan-18      NaN      NaN    NaN       NaN     NaN   NaN       NaN
# 25  26-Jan-18      NaN      NaN    NaN       NaN     NaN   NaN       NaN
#
#     MaxPrice  ModalPrice PriceDate  weekday
# 12       NaN         NaN       NaN      5.0
# 14       NaN         NaN       NaN      0.0
# 19       NaN         NaN       NaN      5.0
# 24       NaN         NaN       NaN      3.0
# 25       NaN         NaN       NaN      4.0
# Null rows:  Int64Index([ 12,  14,  19,  24,  25,  26,  40,  43,  59,  66,
#             ...
#             677, 683, 691, 712, 723, 726, 740, 744, 754, 768],
#            dtype='int64', length=172)
# Number of null rows:  172

# %% [markdown]
# ### Some Plots exploring the Data

# %%
plt.title("Plotting all data, daywise min-price")
plt.plot(beansData[beansData.Market == 'Binny Mill (F&V), Bangalore'].ModalPrice)
plt.show()

# %%
# Plots for the modal price changes vs day number (index) for different weekdays, before interpolation
 
days = ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
for i in range(7):
    plt.title(days[i])
    plt.plot(finalFrameBinny[finalFrameBinny.weekday == float(i)].ModalPrice)
    plt.show()

# %% [markdown]
# ### Interpolation on null rows

# %%
print(rowFiller(101)) #trying the function
# Out:
# 2533.3333333333335 3200.0 2866.6666666666665
# date              12-Apr-18
# Sl. No.                 555
# District          Bangalore
# Market           Ramanagara
# Commodity             Beans
# Variety       Beans (Whole)
# Grade                   FAQ
# MinPrice            2533.33
# MaxPrice               3200
# ModalPrice          2866.67
# PriceDate         12-Apr-18
# weekday                   3
# Name: 94, dtype: object
# C:\Users\sunri\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# C:\Users\sunri\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# C:\Users\sunri\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\sunri\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\sunri\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Filling the null rows with the interpolated values

for i in nanIndicesBinny:
#     print(finalFrameBinny.loc[i])
    finalFrameBinny.loc[i] = rowFiller(i)
#     print(finalFrameBinny.loc[i],"\n\n")
# Out:
# 400.0 533.3333333333334 466.6666666666667
# 866.6666666666666 1200.0 1033.3333333333333
# 733.3333333333334 1200.0 966.6666666666666
# 1333.3333333333333 1866.6666666666667 1600.0
# 1200.0 1733.3333333333333 1466.6666666666667
# 1000.0 1666.6666666666667 1333.3333333333333
# 1333.3333333333333 1800.0 1566.6666666666667
# 1666.6666666666667 2200.0 1933.3333333333333
# 1733.3333333333333 2400.0 2066.6666666666665
# 2266.6666666666665 2933.3333333333335 2600.0
# 2333.3333333333335 3000.0 2666.6666666666665
# 2533.3333333333335 3200.0 2866.6666666666665
# 2666.6666666666665 3333.3333333333335 3000.0
# 2200.0
# C:\Users\sunri\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# C:\Users\sunri\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# C:\Users\sunri\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\sunri\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\sunri\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#  2933.3333333333335 2533.3333333333335
# 2933.3333333333335 3600.0 3266.6666666666665
# 3066.6666666666665 3866.6666666666665 3466.6666666666665
# 2666.6666666666665 3600.0 3133.3333333333335
# 2266.6666666666665 2933.3333333333335 2600.0
# 2266.6666666666665 2933.3333333333335 2600.0
# 2133.3333333333335 3066.6666666666665 2600.0
# 3266.6666666666665 3866.6666666666665 3566.6666666666665
# 3466.6666666666665 4333.333333333333 3900.0
# 2800.0 3466.6666666666665 3133.3333333333335
# 2400.0 3066.6666666666665 2733.3333333333335
# 2666.6666666666665 3333.3333333333335 3000.0
# 2533.3333333333335 3200.0 2866.6666666666665
# 3200.0 3866.6666666666665 3533.3333333333335
# 3466.6666666666665 4333.333333333333 3900.0
# 2666.6666666666665 3466.6666666666665 3066.6666666666665
# 2666.6666666666665 3333.3333333333335 3000.0
# 2800.0 3466.6666666666665 3133.3333333333335
# 2800.0 3333.3333333333335 3066.6666666666665
# 2933.3333333333335 3733.3333333333335 3333.3333333333335
# 2133.3333333333335 2933.3333333333335 2533.3333333333335
# 2488.8888888888887 3111.1111111111113 2800.0
# 2666.6666666666665 3288.8888888888887 2977.777777777778
# 3066.6666666666665 3600.0 3333.3333333333335
# 2933.3333333333335 3733.3333333333335 3400.0
# 2400.0 2933.3333333333335 2733.3333333333335
# 3200.0 4000.0 3600.0
# 2400.0 3200.0 2800.0
# 3066.6666666666665 4133.333333333333 3600.0
# 3466.6666666666665 4400.0 4000.0
# 2800.0 3400.0 3166.6666666666665
# 2622.222222222222 3377.7777777777774 3000.0
# 2666.6666666666665 3333.3333333333335 3022.222222222222
# 2955.555555555555 3777.777777777778 3407.4074074074074

# %%
# checking whether any null rows are left after interpolation (that are not Sundays)

print(finalFrame[(np.isnan(finalFrame.ModalPrice)) & (finalFrame.weekday != 6.0) ].head())
nanIndices = finalFrame[(np.isnan(finalFrame.ModalPrice)) & (finalFrame.weekday != 6.0) ].index
print("Null rows: ",nanIndices,"\nNumber of null rows: ",len(nanIndices))
# Out:
# Empty DataFrame
# Columns: [date, Sl. No., District, Market, Commodity, Variety, Grade, MinPrice, MaxPrice, ModalPrice, PriceDate, weekday]
# Index: []
# Null rows:  Int64Index([], dtype='int64')
# Number of null rows:  0

# %% [markdown]
# ### Replotting the weekdays-wise plots (ModalPrice change)

# %%
for i in range(7):
    plt.title(days[i])
    plt.plot(finalFrameBinny[finalFrameBinny.weekday == float(i)].ModalPrice)
    plt.show()

# %% [markdown]
# ## Writing preprocessed data files. 1 per market

# %%
finalFrame.to_csv("beansData//Ramanagara.csv", index= False)
finalFrameBinny.to_csv("beansData//BinnyMill.csv", index= False)

# %%
# Validating written files
print(pd.read_csv("beansData//Ramanagara.csv").head())
print(pd.read_csv("beansData//BinnyMill.csv").head())
# Out:
#         date  Sl. No.   District      Market Commodity        Variety Grade  \
# 0  01-Jan-18    636.0  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ
# 1  02-Jan-18    635.0  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ
# 2  03-Jan-18    634.0  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ
# 3  04-Jan-18    633.0  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ
# 4  05-Jan-18    632.0  Bangalore  Ramanagara     Beans  Beans (Whole)   FAQ
#
#    MinPrice  MaxPrice  ModalPrice  PriceDate  weekday
# 0    1600.0    2000.0      1800.0  01-Jan-18      0.0
# 1    1600.0    2000.0      1800.0  02-Jan-18      1.0
# 2    1600.0    2000.0      1800.0  03-Jan-18      2.0
# 3    1600.0    2000.0      1800.0  04-Jan-18      3.0
# 4    1200.0    1600.0      1400.0  05-Jan-18      4.0
#         date  Sl. No.   District                       Market Commodity  \
# 0  01-Jan-18    493.0  Bangalore  Binny Mill (F&V), Bangalore     Beans
# 1  02-Jan-18    492.0  Bangalore  Binny Mill (F&V), Bangalore     Beans
# 2  03-Jan-18    491.0  Bangalore  Binny Mill (F&V), Bangalore     Beans
# 3  04-Jan-18    490.0  Bangalore  Binny Mill (F&V), Bangalore     Beans
# 4  05-Jan-18    489.0  Bangalore  Binny Mill (F&V), Bangalore     Beans
#
#          Variety Grade  MinPrice  MaxPrice  ModalPrice  PriceDate  weekday
# 0  Beans (Whole)   FAQ    1800.0    2500.0      2200.0  01-Jan-18      0.0
# 1  Beans (Whole)   FAQ    1800.0    2500.0      2000.0  02-Jan-18      1.0
# 2  Beans (Whole)   FAQ    1600.0    2000.0      1800.0  03-Jan-18      2.0
# 3  Beans (Whole)   FAQ    1400.0    1800.0      1600.0  04-Jan-18      3.0
# 4  Beans (Whole)   FAQ    1200.0    1600.0      1400.0  05-Jan-18      4.0
